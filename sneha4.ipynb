# %% [markdown]
# <a href="https://colab.research.google.com/github/snehatanti/regression-model/blob/main/sneha4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-acc2a174-5d86-49ab-aa6c-17236d250ad4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acc2a174-5d86-49ab-aa6c-17236d250ad4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-461ab6b2-013a-4d3d-97b5-be5f6c099307" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-461ab6b2-013a-4d3d-97b5-be5f6c099307">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/dataset.csv')
df1=pd.read_csv('/content/train1.csv')
print(df.head(15))
print(df1.head(15))
# Out:
#    Customer ID Purchase Date Product ID  Price  Discount
# 0         C001      1/1/2022       P001    100        10
# 1         C002      1/2/2022       P002    150        15
# 2         C003      1/3/2022       P003    200        20
# 3         C004      1/4/2022       P001    100        10
# 4         C005      1/5/2022       P002    150        15
# 5         C006      1/6/2022       P003    200        20
# 6         C007      1/7/2022       P004     75         5
# 7         C008      1/8/2022       P005    125        10
# 8         C009      1/9/2022       P006    300        30
# 9         C010     1/10/2022       P001    100        10
# 10        C011     1/11/2022       P002    150        15
# 11        C012     1/12/2022       P003    200        20
# 12        C013     1/13/2022       P004     75         5
# 13        C014     1/14/2022       P005    125        10
# 14        C015     1/15/2022       P006    300        30
#     PassengerId  Survived  Pclass  \
# ...

# %%
df.describe()
# Out:
#             Price   Discount
# count   30.000000  30.000000
# mean   156.666667  15.000000
# std     70.384821   7.656415
# min     75.000000   5.000000
# 25%    100.000000  10.000000
# 50%    150.000000  15.000000
# 75%    200.000000  20.000000
# max    300.000000  30.000000

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (30, 5)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Purchase Date', 'Product ID', 'Price', 'Discount'], dtype='object')

# %%
df.dtypes
# Out:
# Customer ID      object
# Purchase Date    object
# Product ID       object
# Price             int64
# Discount          int64
# dtype: object

# %%
pclass23=df1[df1["Pclass"].isin([2,3])]
pclass23.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
pclass23=df1[df1["Pclass"].isin([2,3])]
pclass23.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
agenonull=df1[df1["Age"].notna()]
agenonull.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
anames=df1.loc[df1["Age"]>35,"Name"]
anames.head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %%
df1.iloc[9:25,1:8]
a1=df1.iloc[0:3,3]="anonymous"
print(a1)
# Out:
# anonymous

# %%
print("MEAN AGE OF PASSENGER ON BOARD",df1["Age"].mean())
# Out:
# MEAN AGE OF PASSENGER ON BOARD 29.69911764705882

# %%
print("MEDIAN VALUE OF PASSENGERSAGE AND FARE ON BOARD",df1[["Age","Fare"]].median())
# Out:
# MEDIAN VALUE OF PASSENGERSAGE AND FARE ON BOARD Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
df1[["Age","Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df1[["Age","Sex"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df1[["Age","Sex"]].groupby("Sex").min()
# Out:
#          Age
# Sex
# female  0.75
# male    0.42

# %%
df1[["Age","Sex"]].groupby("Sex").max()
# Out:
#          Age
# Sex
# female  63.0
# male    80.0

# %%
df1[["Age","Sex"]].groupby("Sex").first()
# Out:
#          Age
# Sex
# female  38.0
# male    22.0

# %%
df1.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df1.groupby(["Sex","Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
df1.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
df1["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df1.sort_values(by="Age",ascending=True).head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df1.sort_values(by=["Pclass","Age"],ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
df1["Name"].str.lower()
# Out:
# 0                                         anonymous
# 1                                         anonymous
# 2                                         anonymous
# 3      futrelle, mrs. jacques heath (lily may peel)
# 4                          allen, mr. william henry
#                            ...
# 886                           montvila, rev. juozas
# 887                    graham, miss. margaret edith
# 888        johnston, miss. catherine helen "carrie"
# 889                           behr, mr. karl howell
# 890                             dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
print(df1.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                     anonymous    male  22.0      1      0
# 1                                     anonymous  female  38.0      1      0
# 2                                     anonymous  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df1["Name"].str.split(",")
df1["surname"]=df1["Name"].str.split(",").str.get(1)
print("SURNAME OF THE PASSENGERS",df1["surname"])
# Out:
# SURNAME OF THE PASSENGERS 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3       Mrs. Jacques Heath (Lily May Peel)
# 4                        Mr. William Henry
#                       ...
# 886                            Rev. Juozas
# 887                   Miss. Margaret Edith
# 888         Miss. Catherine Helen "Carrie"
# 889                        Mr. Karl Howell
# 890                            Mr. Patrick
# Name: surname, Length: 891, dtype: object

# %%
df1["RealName"]=df1["Name"].str.split(",").str.get(0)
print("REAL NAME OF THE PASSENGERS",df1["RealName"])
# Out:
# REAL NAME OF THE PASSENGERS 0      anonymous
# 1      anonymous
# 2      anonymous
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: RealName, Length: 891, dtype: object
